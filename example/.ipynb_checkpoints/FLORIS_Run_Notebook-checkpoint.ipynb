# %% [markdown]
# # Examples for running FLORIS

# %%
# load modules
from floris.Floris import Floris

# %% [markdown]
# ## Setup floris and process input file

# %%
floris = Floris("floris.json")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\users\jannoni\desktop\repos\floris5\floris\floris\Floris.py in __init__(self, input_file)
#      24         try:
# ---> 25             FlorisUnitTest().run_tests()
#      26         except AssertionError:
#
# c:\users\jannoni\desktop\repos\floris5\floris\tests\FlorisUnit.py in run_tests(self)
#      26         self.coordinate.test_all()
# ---> 27         self.flowfield.test_all()
#
# c:\users\jannoni\desktop\repos\floris5\floris\tests\FlowField_test.py in test_all(self)
#      62         test_map_coordinate_to_index_xmin()
# ---> 63         test_map_coordinate_to_index_xmid()
#      64         test_map_coordinate_to_index_xmax()
#
# c:\users\jannoni\desktop\repos\floris5\floris\tests\FlowField_test.py in test_map_coordinate_to_index_xmid()
#     127     xi, _, __ = test_instance._map_coordinate_to_index(Coordinate(mid, 0))
# --> 128     assert xi == 99
#     129
#
# AssertionError:
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-7db0eb873bdb> in <module>()
# ----> 1 floris = Floris("floris.json")
#
# c:\users\jannoni\desktop\repos\floris5\floris\floris\Floris.py in __init__(self, input_file)
#      27             error = "floris unit tests failed. " \
#      28                 + "Run the standalone pytest framework to debug."
# ---> 29             raise RuntimeError(error)
#      30
#      31         self.input_reader = InputReader()
#
# RuntimeError: floris unit tests failed. Run the standalone pytest framework to debug.

# %% [markdown]
# ## Calculate Wake

# %%
import time
import cProfile, pstats, io

t1 = time.time()

pr = cProfile.Profile()
pr.enable()

floris.farm.flow_field.calculate_wake()

pr.disable()

t2 = time.time()

print(t2-t1)
# Out:
# 7.517999887466431

# %%
s = io.StringIO()
sortby = 'cumulative'
ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
ps.print_stats()
print(s.getvalue())
# Out:
#          10006 function calls in 7.518 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    7.518    3.759 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2851(run_code)
#         2    0.000    0.000    7.518    3.759 {built-in method builtins.exec}
#         1    0.006    0.006    7.518    7.518 <ipython-input-16-d844fe846bdf>:9(<module>)
#         1    0.025    0.025    7.512    7.512 c:\users\jannoni\desktop\repos\floris5\floris\floris\FlowField.py:128(calculate_wake)
#         4    0.071    0.018    4.394    1.098 c:\users\jannoni\desktop\repos\floris5\floris\floris\FlowField.py:102(_compute_turbine_velocity_deficit)
#         4    4.323    1.081    4.323    1.081 c:\users\jannoni\desktop\repos\floris5\floris\floris\WakeVelocity.py:150(_gauss)
#         4    0.062    0.015    2.131    0.533 c:\users\jannoni\desktop\repos\floris5\floris\floris\FlowField.py:106(_compute_turbine_wake_deflection)
#         4    2.069    0.517    2.069    0.517 c:\users\jannoni\desktop\repos\floris5\floris\floris\WakeDeflection.py:64(_gauss_deflection)
#         4    0.000    0.000    0.573    0.143 c:\users\jannoni\desktop\repos\floris5\floris\floris\WakeCombination.py:29(combine)
#         4    0.573    0.143    0.573    0.143 c:\users\jannoni\desktop\repos\floris5\floris\floris\WakeCombination.py:43(_sosfs)
#         4    0.029    0.007    0.241    0.060 c:\users\jannoni\desktop\repos\floris5\floris\floris\Turbine.py:192(update_quantities)
#         8    0.137    0.017    0.211    0.026 c:\users\jannoni\desktop\repos\floris5\floris\floris\Turbine.py:155(_calculate_swept_area_velocities)
#         2    0.005    0.003    0.094    0.047 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:112(unique)
#         2    0.076    0.038    0.076    0.038 {method 'sort' of 'numpy.ndarray' objects}
#       128    0.000    0.000    0.056    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\interpolate\ndgriddata.py:88(griddata)
#         1    0.055    0.055    0.055    0.055 c:\users\jannoni\desktop\repos\floris5\floris\floris\FlowField.py:110(_rotated_grid)
#       128    0.036    0.000    0.045    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\interpolate\ndgriddata.py:58(__init__)
#       558    0.026    0.000    0.026    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       264    0.000    0.000    0.014    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2154(amax)
#       264    0.000    0.000    0.013    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\_methods.py:25(_amax)
#       136    0.000    0.000    0.012    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2255(amin)
#       136    0.000    0.000    0.012    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\_methods.py:28(_amin)
#         2    0.011    0.006    0.011    0.006 {method 'flatten' of 'numpy.ndarray' objects}
#       128    0.000    0.000    0.009    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\interpolate\ndgriddata.py:67(__call__)
#       128    0.003    0.000    0.006    0.000 {method 'query' of 'scipy.spatial.ckdtree.cKDTree' objects}
#       256    0.002    0.000    0.005    0.000 {built-in method scipy.interpolate.interpnd._ndim_coords_from_arrays}
#       256    0.001    0.000    0.003    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\stride_tricks.py:196(broadcast_arrays)
#      1960    0.002    0.000    0.002    0.000 {built-in method numpy.core.multiarray.array}
#         2    0.002    0.001    0.002    0.001 {built-in method numpy.core.multiarray.concatenate}
#       128    0.000    0.000    0.001    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2388(prod)
#       128    0.000    0.000    0.001    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\_methods.py:34(_prod)
#       640    0.000    0.000    0.001    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\numeric.py:586(ascontiguousarray)
#       256    0.000    0.000    0.001    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\stride_tricks.py:248(<listcomp>)
#       256    0.001    0.000    0.001    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\stride_tricks.py:177(_broadcast_shape)
#       256    0.000    0.000    0.001    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:138(reshape)
#         4    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\Turbine.py:99(_calculate_cp)
#       256    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         8    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\interpolate\polyint.py:62(__call__)
#       256    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:55(_wrapfunc)
#        14    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2786(mean)
#         4    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\Turbine.py:147(fCp)
#        14    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\_methods.py:53(_mean)
#       280    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\numeric.py:463(asarray)
#      1024    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\stride_tricks.py:252(<genexpr>)
#        12    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\Turbine.py:215(get_average_velocity)
#         8    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\interpolate\interpolate.py:627(_evaluate)
#       264    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\Turbine.py:102(_calculate_ct)
#       272    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\numeric.py:534(asanyarray)
#       128    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\numeric.py:2160(isscalar)
#         8    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\interpolate\polyint.py:88(_prepare_x)
#         8    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\_lib\_util.py:192(_asarray_validated)
#         4    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\Turbine.py:150(fCt)
#         4    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\Turbine.py:105(_calculate_power)
#         8    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\interpolate\interpolate.py:642(_check_bounds)
#         2    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\codeop.py:132(__call__)
#         8    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\interpolate\interpolate.py:569(_call_linear_np)
#         1    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\TurbineMap.py:43(rotated)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#        14    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\_methods.py:43(_count_reduce_items)
#         8    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:1771(interp)
#         9    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.zeros}
#       272    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#       256    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#       188    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       256    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        16    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#       128    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:1549(shape)
#        16    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\_methods.py:37(_any)
#         4    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\Coordinate.py:47(rotate_z)
#         4    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\Turbine.py:113(_calculate_ai)
#         8    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\numerictypes.py:728(issubdtype)
#         5    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\Coordinate.py:27(__init__)
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.interp}
#         1    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\TurbineMap.py:56(sorted_in_x_as_list)
#         8    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\interpolate\polyint.py:94(_finish_y)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        52    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         8    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\type_check.py:237(iscomplexobj)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         8    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\ma\core.py:6064(isMaskedArray)
#         8    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\numerictypes.py:660(issubclass_)
#        14    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         8    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\sparse\base.py:1202(isspmatrix)
#         4    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\Wake.py:40(get_velocity_function)
#         4    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\Wake.py:37(get_deflection_function)
#         1    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\TurbineMap.py:28(__init__)
#         2    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\hooks.py:139(__call__)
#         1    0.000    0.000    0.000    0.000 <ipython-input-16-d844fe846bdf>:11(<module>)
#         8    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\utils\ipstruct.py:125(__getattr__)
#         1    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\TurbineMap.py:40(items)
#         4    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\Coordinate.py:41(as_tuple)
#         2    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:1065(user_global_ns)
#         6    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\BaseObject.py:19(__init__)
#         1    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\TurbineMap.py:34(<listcomp>)
#         1    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\TurbineMap.py:58(<listcomp>)
#         4    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\TurbineMap.py:57(<lambda>)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\hooks.py:204(pre_run_code_hook)
#         1    0.000    0.000    0.000    0.000 c:\users\jannoni\desktop\repos\floris5\floris\floris\TurbineMap.py:35(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# ## Compute Velocities at each Turbine

# %%
for coord, turbine in floris.farm.turbine_map.items():
    print(str(coord) + ":")
    print("\tCp -", turbine.Cp)
    print("\tCt -", turbine.Ct)
    print("\tpower -", turbine.power)
    print("\tai -", turbine.aI)
    print("\taverage velocity -", turbine.get_average_velocity())
# Out:
# (0.0, 0.0):
# 	Cp - 0.46328565533974125
# 	Ct - 0.7660614834442518
# 	power - 1722147.60758
# 	ai - 0.258164044983
# 	average velocity - 7.86613661748
# (800.0, 0.0):
# 	Cp - 0.46131557634929915
# 	Ct - 0.8041959658822297
# 	power - 1033310.9486
# 	ai - 0.278751251914
# 	average velocity - 6.64403557511
# (0.0, 600.0):
# 	Cp - 0.46328565533974125
# 	Ct - 0.7660614834442518
# 	power - 1722147.60758
# 	ai - 0.258164044983
# 	average velocity - 7.86613661748
# (800.0, 600.0):
# 	Cp - 0.46131557634929915
# 	Ct - 0.8041959658822297
# 	power - 1033310.9486
# 	ai - 0.278751251914
# 	average velocity - 6.64403557511

# %% [markdown]
# ## Plot the Flow Field (z-plane)

# %%
# this plots the streamwise velocity at:

# inputs -> percent of z domain entered as a list

#     1.  20% of the z height domain (the z height domain is 2x hub height, i.e. 36m)
#     2.  50% of the z height domain (at hub height)
#     3.  80% of the z height domain (144m)

floris.farm.flow_field.plot_z_planes([0.2, 0.5, 0.8])

# %% [markdown]
# ## Plot the Flow Field (x-plane)

# %%
# plot a cut-through of the flow field at a particular x distance downstream.

# inputs -> percent of x domain entered as a list 

floris.farm.flow_field.plot_x_planes([0.4])

# %% [markdown]
# ## Optimize Wind Farm using Wake Steering

# %%
import OptModules  # modules used for optimizing FLORIS
import numpy as np

turbines      = [turbine for _, turbine in floris.farm.flow_field.turbine_map.items()]
power_initial = np.sum([turbine.power for turbine in turbines])  # determine initial power production

# set bounds for the optimization on the yaw angles (deg)
minimum_yaw_angle = 0.0
maximum_yaw_angle = 20.0

# compute the optimal yaw angles
opt_yaw_angles = OptModules.wake_steering(floris,minimum_yaw_angle,maximum_yaw_angle)

print('Optimal yaw angles for:')
for i,yaw in enumerate(opt_yaw_angles):
    print('Turbine ', i, ' yaw angle = ', np.degrees(opt_yaw_angles))
# Out:
# =====================================================================
# Optimizing wake redirection control...
# Number of parameters to optimize =  4
# =====================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-fd1a4e49bd44> in <module>()
#       8 maximum_yaw_angle = 20.0
#       9
# ---> 10 opt_yaw_angles = OptModules.wake_steering(floris,minimum_yaw_angle,maximum_yaw_angle)
#      11
#      12 print('Optimal yaw angles for:')
#
# C:\Users\jannoni\Desktop\Repos\FLORIS5\FLORIS\example\OptModules.py in wake_steering(floris, minimum_yaw_angle, maximum_yaw_angle)
#      51         print('=====================================================================')
#      52
# ---> 53         residual_plant = minimize(optimize_plant,x0,args=(floris),method='SLSQP',bounds=bnds,options={'ftol':0.001,'eps':0.05})
#      54
#      55         # %%
#
# C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     493     elif meth == 'slsqp':
#     494         return _minimize_slsqp(fun, x0, args, jac, bounds,
# --> 495                                constraints, callback=callback, **options)
#     496     elif meth == 'dogleg':
#     497         return _minimize_dogleg(fun, x0, args, jac, hess,
#
# C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\optimize\slsqp.py in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, **unknown_options)
#     400             # Compute the derivatives of the objective function
#     401             # For some reason SLSQP wants g dimensioned to n+1
# --> 402             g = append(fprime(x), 0.0)
#     403
#     404             # Compute the normals of the constraints
#
# C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\optimize\slsqp.py in approx_jacobian(x, func, epsilon, *args)
#      56     """
#      57     x0 = asfarray(x)
# ---> 58     f0 = atleast_1d(func(*((x0,)+args)))
#      59     jac = zeros([len(x0), len(f0)])
#      60     dx = zeros(len(x0))
#
# C:\Users\jannoni\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# C:\Users\jannoni\Desktop\Repos\FLORIS5\FLORIS\example\OptModules.py in optimize_plant(x, floris)
#      28         turbine.yaw_angle = x[i]
#      29
# ---> 30     floris.farm.flow_field.calculate_wake()
#      31
#      32     turbines    = [turbine for _, turbine in floris.farm.flow_field.turbine_map.items()]
#
# c:\users\jannoni\desktop\repos\floris5\floris\floris\FlowField.py in calculate_wake(self)
#     155
#     156             # get the wake deflecton field
# --> 157             deflection = self._compute_turbine_wake_deflection(rotated_x, rotated_y, turbine, coord, self)
#     158
#     159             # get the velocity deficit accounting for the deflection
#
# c:\users\jannoni\desktop\repos\floris5\floris\floris\FlowField.py in _compute_turbine_wake_deflection(self, x, y, turbine, coord, flowfield)
#     106     def _compute_turbine_wake_deflection(self, x, y, turbine, coord, flowfield):
#     107         deflection_function = self.wake.get_deflection_function()
# --> 108         return deflection_function(x, y, turbine, coord, flowfield)
#     109
#     110     def _rotated_grid(self, angle, center_of_rotation):
#
# c:\users\jannoni\desktop\repos\floris5\floris\floris\WakeDeflection.py in _gauss_deflection(self, x_locations, y_locations, turbine, coord, flowfield)
#     122         sigma_y = ky*( x_locations - x0 ) + sigma_y0
#     123         sigma_z = kz*( x_locations - x0 ) + sigma_z0
# --> 124         sigma_y[x_locations < x0] = sigma_y0[x_locations < x0]
#     125         sigma_z[x_locations < x0] = sigma_z0[x_locations < x0]
#     126
#
# KeyboardInterrupt:

# %% [markdown]
# ## Assign New Yaw Angles

# %%
# assign yaw angles to turbines
turbines    = [turbine for _, turbine in floris.farm.flow_field.turbine_map.items()]
for i,turbine in enumerate(turbines):
    turbine.yaw_angle = opt_yaw_angles[i]

# %% [markdown]
# ## Plot Optimized Flow Field

# %%
# compute the new wake with yaw angles
floris.farm.flow_field.calculate_wake()

# optimal power 
power_opt = np.sum([turbine.power for turbine in turbines]) 

# plot results
floris.farm.flow_field.plot_flow_field_Zplane()

print('Power increased by ', 100*(powerOpt-power_opt)/power_initial)
